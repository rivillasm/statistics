# %% [markdown]
# ![image.png](attachment:73457219-297a-4dbb-b87f-d60dfa92936a.png)

# %% [markdown]
# ![image.png](attachment:10a304ba-f244-46ff-bac9-58a0cf17767c.png)

# %% [markdown]
# ![image.png](attachment:8e83352f-21a9-4302-94e7-7a474e69d936.png)

# %% [markdown]
# ![image.png](attachment:6a5ae3bf-b85b-4e87-9652-453c7d32f93a.png)

# %% [markdown]
# # Confusion matrix

# %% [markdown]
# ![image.png](attachment:3914a873-fe93-437b-8ecf-cf2436f3d46b.png)

# %% [markdown]
# ![image.png](attachment:58022fbb-c169-4c36-a362-59a76849276c.png)

# %% [markdown]
# ![image.png](attachment:06f91b51-98a6-44dd-87b7-5b50a6079549.png)

# %% [markdown]
# ![image.png](attachment:15ef3227-cfee-424a-82a9-d966e960b6d3.png)

# %% [markdown]
# ![image.png](attachment:b9bf554f-4a89-4d20-9d4e-1b16eeb3bd1a.png)

# %% [markdown]
# ![image.png](attachment:cf66180f-6362-4518-a621-4e8f01879b67.png)

# %% [markdown]
# ![image.png](attachment:ffa68fc9-a510-4a75-bd13-1b62c3f070cc.png)

# %% [markdown]
# ![image.png](attachment:4e78dce9-752f-48d4-9e00-84b454301a27.png)
# * precission = out of the total +ve predicted by the model what is the % of the actual true +ve predicted

# %% [markdown]
# * Example of bad model with inbalanced dataset, the model will predict everything +ve in this case and provide a good accuracy but we know is not correct
# ![image.png](attachment:02a86f6f-c564-4702-a851-379080a2496d.png)
# ### Note - do not use ACCURACY when your dataset is INBALANCED

# %% [markdown]
# * By looking at the rates when analyzing your results we always expect TPR & TNR to be high and FPR & FNR to be low
# * in the case below we can see that TPR is high but TNR is low so right there we can assume the data is unbalanced and we need to take other apporaches
# ![image.png](attachment:651f7ccb-e102-442a-a0b1-f4b1105da2d5.png)

# %% [markdown]
# # 1 tail and 2 trail test

# %% [markdown]
# ![image.png](attachment:17a3c8b3-031d-4ce8-8326-382500a74613.png)

# %% [markdown]
# ![image.png](attachment:961857be-051f-4d29-a6e4-39a5b29fd40a.png)
