# %% [markdown]
# # ANOVA
#
# ![image.png](attachment:109e8641-7e92-45fc-9820-7393fb444606.png)

# %% [markdown]
# ![image.png](attachment:cf84f5a9-89d3-46e5-9b2a-c20fccf1b9d2.png)

# %% [markdown]
# ![image.png](attachment:3ac6bf54-686a-4ed9-82a7-ea9ee461b8ad.png)

# %% [markdown]
# ![image.png](attachment:ad13e43a-4ada-4494-9b77-0248698acc70.png)

# %% [markdown]
# # EXAMPLE 1
#
# ![image.png](attachment:6da5a407-797c-41dc-af76-29b308fdbb23.png)

# %%
import pandas as pd
# load data file
df = pd.read_csv("https://reneshbedre.github.io/assets/posts/anova/onewayanova.txt", sep="\t")
df
# Out:
#     A   B   C   D
# 0  25  45  30  54
# 1  30  55  29  60
# 2  28  29  33  51
# 3  36  56  37  62
# 4  29  40  27  73

# %%
# reshape the d dataframe suitable for statsmodels package 
df_melt = pd.melt(df.reset_index(), id_vars=['index'], value_vars=['A', 'B', 'C', 'D'])
df_melt
# Out:
#     index variable  value
# 0       0        A     25
# 1       1        A     30
# 2       2        A     28
# 3       3        A     36
# 4       4        A     29
# 5       0        B     45
# 6       1        B     55
# 7       2        B     29
# 8       3        B     56
# 9       4        B     40
# 10      0        C     30
# 11      1        C     29
# 12      2        C     33
# 13      3        C     37
# 14      4        C     27
# 15      0        D     54
# 16      1        D     60
# 17      2        D     51
# 18      3        D     62
# 19      4        D     73

# %%
# replace column names
df_melt.columns = ['index', 'treatments', 'value']

# generate a boxplot to see the data distribution by treatments. Using boxplot, we can 
# easily detect the differences between different treatments


import matplotlib.pyplot as plt
import seaborn as sns
ax = sns.boxplot(x='treatments', y='value', data=df_melt, color='#99c2a2')
ax = sns.swarmplot(x="treatments", y="value", data=df_melt, color='#7d0013')
plt.show()

# %%
import scipy.stats as stats

# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df['A'], df['B'], df['C'], df['D'])
print(fvalue, pvalue)
# Out:
# 17.492810457516338 2.639241146210922e-05

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('value ~ C(treatments)', data=df_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# output (ANOVA F and p value)
# Out:
#                 sum_sq    df         F    PR(>F)
# C(treatments)  3010.95   3.0  17.49281  0.000026
# Residual        918.00  16.0       NaN       NaN

# %%
# ANOVA table using bioinfokit v1.0.3 or later (it uses wrapper script for anova_lm)
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=df_melt, res_var='value', anova_model='value ~ C(treatments)')
res.anova_summary
# output (ANOVA F and p value)

# note: if the data is balanced (equal sample size for each group), Type 1, 2, and 3 sums of squares
# (typ parameter) will produce similar results.
# Out:
#                  df   sum_sq   mean_sq         F    PR(>F)
# C(treatments)   3.0  3010.95  1003.650  17.49281  0.000026
# Residual       16.0   918.00    57.375       NaN       NaN

# %% [markdown]
# ![image.png](attachment:68934880-5827-4370-b13f-a0019104096e.png)

# %% [markdown]
# ![image.png](attachment:f939e8bc-9886-4048-a9f5-3a1514c03f90.png)

# %% [markdown]
# ![image.png](attachment:359064e3-c17b-4c66-94c5-04ca5cdc91c9.png)

# %%
# we will use bioinfokit (v1.0.3 or later) for performing tukey HSD test
# check documentation here https://github.com/reneshbedre/bioinfokit

from bioinfokit.analys import stat

# perform multiple pairwise comparison (Tukey's HSD)
# unequal sample size data, tukey_hsd uses Tukey-Kramer test

res = stat()
res.tukey_hsd(df=df_melt, res_var='value', xfac_var='treatments', anova_model='value ~ C(treatments)')
res.tukey_summary


# Note: p-value 0.001 from tukey_hsd output should be interpreted as <=0.001
# Out:
# C:\Users\rivil\anaconda3\lib\site-packages\bioinfokit\analys.py:402: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mult_group[ele] = df[df[xfac_var] == ele].mean().loc[res_var]
#   group1 group2  Diff      Lower      Upper   q-value   p-value
# 0      A      B  15.4   1.692871  29.107129  4.546156  0.025070
# 1      A      C   1.6 -12.107129  15.307129  0.472328  0.900000
# 2      A      D  30.4  16.692871  44.107129  8.974231  0.001000
# 3      B      C  13.8   0.092871  27.507129  4.073828  0.048178
# 4      B      D  15.0   1.292871  28.707129  4.428074  0.029578
# 5      C      D  28.8  15.092871  42.507129  8.501903  0.001000

# %% [markdown]
# ![image.png](attachment:e4737f0c-7b00-4351-a5c7-ad6c14a8bdc8.png)

# %% [markdown]
# ![image.png](attachment:3dc64195-8ca4-430c-8c8d-a9908f260783.png)

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt

# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ![image.png](attachment:a4243770-1d28-4e1f-b0cb-f1ffc635f1bd.png)

# %% [markdown]
# ![image.png](attachment:1de9904d-a4fd-458f-8494-c02da874e7a8.png)

# %%
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print(w, pvalue)
# Out:
# 0.9685018062591553 0.7229723930358887

# %% [markdown]
# ![image.png](attachment:95f16ac4-87ed-4696-9373-b9902e637332.png)

# %%
import scipy.stats as stats

w, pvalue = stats.bartlett(df['A'], df['B'], df['C'], df['D'])
print(w, pvalue)


# if you have a stacked table, you can use bioinfokit v1.0.3 or later for the bartlett's test
from bioinfokit.analys import stat 
res = stat()
res.bartlett(df=df_melt, res_var='value', xfac_var='treatments')
res.bartlett_summary
# Out:
# 5.687843565012841 0.1278253399753447
#                  Parameter   Value
# 0      Test statistics (T)  5.6878
# 1  Degrees of freedom (Df)  3.0000
# 2                  p value  0.1278

# %% [markdown]
# ![image.png](attachment:00b5f8c0-741d-46b7-84a4-2f9e038bdec7.png)

# %%
# if you have a stacked table, you can use bioinfokit v1.0.3 or later for the Levene's test
from bioinfokit.analys import stat 
res = stat()
res.levene(df=df_melt, res_var='value', xfac_var='treatments')
res.levene_summary
# Out:
#                  Parameter   Value
# 0      Test statistics (W)  1.9220
# 1  Degrees of freedom (Df)  3.0000
# 2                  p value  0.1667

# %% [markdown]
# ![image.png](attachment:616d3f26-9c53-46fc-81d9-ee64cc00f2a9.png)

# %% [markdown]
# # Example TWO WAY ANOVA
#
# ![image.png](attachment:fada9a45-33ab-403a-a547-07787b0e419b.png)

# %%
import pandas as pd
import seaborn as sns
# load data file
d = pd.read_csv("https://reneshbedre.github.io/assets/posts/anova/twowayanova.txt", sep="\t")
d
# Out:
#    Genotype  1_year  2_year  3_year
# 0         A    1.53    4.08    6.69
# 1         A    1.83    3.84    5.97
# 2         A    1.38    3.96    6.33
# 3         B    3.60    5.70    8.55
# 4         B    2.94    5.07    7.95
# 5         B    4.02    7.20    8.94
# 6         C    3.99    6.09   10.02
# 7         C    3.30    5.88    9.63
# 8         C    4.41    6.51   10.38
# 9         D    3.75    5.19   11.40
# 10        D    3.63    5.37    9.66
# 11        D    3.57    5.55   10.53
# 12        E    1.71    3.60    6.87
# 13        E    2.01    5.10    6.93
# 14        E    2.04    6.99    6.84
# 15        F    3.96    5.25    9.84
# 16        F    4.77    5.28    9.87
# 17        F    4.65    5.07   10.08

# %%
# reshape the d dataframe suitable for statsmodels package 
# you do not need to reshape if your data is already in stacked format. Compare d and d_melt tables for detail 
# understanding 
d_melt = pd.melt(d, id_vars=['Genotype'], value_vars=['1_year', '2_year', '3_year'])
# replace column names
d_melt.columns = ['Genotype', 'years', 'value']
d_melt.head()
# Out:
#   Genotype   years  value
# 0        A  1_year   1.53
# 1        A  1_year   1.83
# 2        A  1_year   1.38
# 3        B  1_year   3.60
# 4        B  1_year   2.94

# %% [markdown]
# As there are 6 and 3 levels for genotype and years, respectively, this is a 6 x 3 factorial design yielding 18 unique combinations for measurement of the response variable.

# %%
# generate a boxplot to see the data distribution by genotypes and years. Using boxplot, we can easily detect the 
# differences between different groups
sns.boxplot(x="Genotype", y="value", hue="years", data=d_melt, palette="Set3")
# Out:
# <AxesSubplot:xlabel='Genotype', ylabel='value'>

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('value ~ C(Genotype) + C(years) + C(Genotype):C(years)', data=d_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                           sum_sq    df           F        PR(>F)
# C(Genotype)            58.551733   5.0   32.748581  1.931655e-12
# C(years)              278.925633   2.0  390.014868  4.006243e-25
# C(Genotype):C(years)   17.122967  10.0    4.788525  2.230094e-04
# Residual               12.873000  36.0         NaN           NaN

# %%
# ANOVA table using bioinfokit v1.0.3 or later (it uses wrapper script for anova_lm)
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=d_melt, res_var='value', anova_model='value~C(Genotype)+C(years)+C(Genotype):C(years)')
res.anova_summary
# Out:
#                         df      sum_sq     mean_sq           F        PR(>F)
# C(Genotype)            5.0   58.551733   11.710347   32.748581  1.931655e-12
# C(years)               2.0  278.925633  139.462817  390.014868  4.006243e-25
# C(Genotype):C(years)  10.0   17.122967    1.712297    4.788525  2.230094e-04
# Residual              36.0   12.873000    0.357583         NaN           NaN

# %% [markdown]
# ![image.png](attachment:e2418a99-40d3-46fd-b2de-acb6cdc44501.png)

# %% [markdown]
# ![image.png](attachment:26a26ba8-7d0f-4539-8b4c-ef7960d8f5c9.png)

# %%
from statsmodels.graphics.factorplots import interaction_plot
import matplotlib.pyplot as plt
fig = interaction_plot(x=d_melt['Genotype'], trace=d_melt['years'], response=d_melt['value'], 
    colors=['#4c061d','#d17a22', '#b4c292'])
plt.show()

# %% [markdown]
# ![image.png](attachment:93867ea6-fc1b-4bde-a16b-366e54b49a35.png)
